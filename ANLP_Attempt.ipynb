# %%
# !unzip hw2_colab.zip
# Out:
# Archive:  hw2_colab.zip
#    creating: data/
#   inflating: data/faiss_mapping.json
#    creating: data/bm25_index/
#   inflating: data/bm25_index/params.index.json
#   inflating: data/bm25_index/vocab.index.json
#   inflating: data/bm25_index/indices.csc.index.npy
#   inflating: data/bm25_index/data.csc.index.npy
#   inflating: data/bm25_index/indptr.csc.index.npy
#   inflating: data/bm25_index/mapping.json
#   inflating: data/faiss_index.bin
#   inflating: data/knowledge_base.jsonl
#    creating: RAG/
#   inflating: RAG/retriever.py
#    creating: RAG/__pycache__/
#   inflating: RAG/__pycache__/sparse_embedder.cpython-313.pyc
#   inflating: RAG/__pycache__/document_query_embedder.cpython-313.pyc
#   inflating: RAG/__pycache__/retriever.cpython-313.pyc
#   inflating: RAG/sparse_embedder.py
#   inflating: RAG/document_query_embedder.py
#    creating: LLM/
#   inflating: LLM/run_evaluation.py
#   inflating: LLM/llm.py
#    creating: LLM/__pycache__/
# ...

# %%
# !nvidia-smi
# Out:
# Fri Feb 27 16:58:08 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA RTX PRO 6000 Blac...    Off |   00000000:05:00.0 Off |                    0 |
# | N/A   33C    P0             48W /  600W |       0MiB /  97887MiB |      0%      Default |
# |                                         |                        |             Disabled |
# ...

# %%
# !pip install transformers accelerate faiss-gpu-cu12 bm25s nltk beautifulsoup4 pdfplumber
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 4.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.1/68.1 kB 8.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.4/48.4 MB 49.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 kB 9.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 8.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 160.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 141.8 MB/s eta 0:00:00
# ...

# %%
# !export JAX_PLATFORMS=cpu PYTHONPATH=$(pwd) && python data_pipeline/run_pipeline.py
# Out:
# ...
# STEP 1: Scraping Websites
# ...
# Beginning scraping/caching for 296 URLs...
# Skipping https://en.wikipedia.org/wiki/Andy_Warhol (already downloaded)
# Skipping https://en.wikipedia.org/wiki/Randy_Pausch (already downloaded)
# Skipping https://en.wikipedia.org/wiki/The_Last_Lecture (already downloaded)
# Skipping https://en.wikipedia.org/wiki/Scott_Fahlman (already downloaded)
# Skipping https://en.wikipedia.org/wiki/Zachary_Quinto (already downloaded)
# Skipping https://en.wikipedia.org/wiki/Andy_Bechtolsheim (already downloaded)
# Skipping https://en.wikipedia.org/wiki/James_Gosling (already downloaded)
# Skipping https://en.wikipedia.org/wiki/Ivan_Sutherland (already downloaded)
# Skipping https://en.wikipedia.org/wiki/Richard_B._Mellon (already downloaded)
# Skipping https://en.wikipedia.org/wiki/College_of_Fine_Arts_(Carnegie_Mellon_University) (already downloaded)
# Skipping https://en.wikipedia.org/wiki/Alice_(software) (already downloaded)
# ...

# %%
# !zip -r /content/data.zip /content/data
from google.colab import files
files.download("/content/data.zip")
# Out:
# updating: content/data/ (stored 0%)
# updating: content/data/faiss_index.bin (deflated 7%)
# updating: content/data/faiss_mapping.json (deflated 70%)
# updating: content/data/bm25_index/ (stored 0%)
# updating: content/data/bm25_index/indptr.csc.index.npy (deflated 80%)
# updating: content/data/bm25_index/mapping.json (deflated 70%)
# updating: content/data/bm25_index/data.csc.index.npy (deflated 20%)
# updating: content/data/bm25_index/indices.csc.index.npy (deflated 66%)
# updating: content/data/bm25_index/params.index.json (deflated 42%)
# updating: content/data/bm25_index/vocab.index.json (deflated 55%)
# updating: content/data/knowledge_base.jsonl (deflated 70%)

# %%
# !export JAX_PLATFORMS=cpu PYTHONPATH=$(pwd) && python LLM/run_evaluation.py
# Out:
# Loading queries from test_set_day_2.json...
# Found 400 questions.
# Initializing Dense Retriever...
# Loading HuggingFace model: BAAI/bge-small-en-v1.5...
# ...
# Loading weights: 100% 199/199 [00:00<00:00, 984.72it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: BAAI/bge-small-en-v1.5
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Model loaded to cuda
# Initializing Sparse Retriever...
# Setting up Hybrid Retriever...
# Loading Generator LLM...
# Loading Generation Model: Qwen/Qwen2.5-1.5B-Instruct...
# Using device: cuda
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100% 338/338 [00:00<00:00, 854.25it/s, Materializing param=model.norm.weight]
#
# Starting generation pipeline...
# ...

# %%
# !export JAX_PLATFORMS=cpu PYTHONPATH=$(pwd) && python LLM/run_evaluation.py
# Out:
# Loading queries from test_set_day_2.json...
# Found 400 questions.
# Initializing Dense Retriever...
# Loading HuggingFace model: BAAI/bge-small-en-v1.5...
# ...
# Loading weights: 100% 199/199 [00:00<00:00, 987.50it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: BAAI/bge-small-en-v1.5
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Model loaded to cuda
# Initializing Sparse Retriever...
# Setting up Hybrid Retriever...
# Loading Generator LLM...
# Loading Generation Model: Qwen/Qwen2.5-1.5B-Instruct...
# Using device: cuda
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100% 338/338 [00:00<00:00, 839.40it/s, Materializing param=model.norm.weight]
#
# Starting generation pipeline...
# ...

# %%
# !export JAX_PLATFORMS=cpu PYTHONPATH=$(pwd) && python LLM/run_evaluation.py
# Out:
# Loading queries from test_set_day_2.json...
# Found 400 questions.
# Initializing Dense Retriever...
# Loading HuggingFace model: BAAI/bge-small-en-v1.5...
# Loading weights: 100% 199/199 [00:00<00:00, 1571.07it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: BAAI/bge-small-en-v1.5
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Model loaded to cuda
# Initializing Sparse Retriever...
# Setting up Hybrid Retriever...
# Loading Generator LLM...
# Loading Generation Model: Qwen/Qwen2.5-1.5B-Instruct...
# Using device: cuda
# ...
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100% 338/338 [00:00<00:00, 855.52it/s, Materializing param=model.norm.weight]
#
# Starting generation pipeline...
# ...

# %%
# !zip -r all_system_outputs.zip system_outputs/
from google.colab import files
files.download("/content/all_system_outputs.zip")
# Out:
# updating: system_outputs/ (stored 0%)
# updating: system_outputs/system_output_day_2_third.json (deflated 65%)
# updating: system_outputs/system_output_6.json (deflated 62%)
# updating: system_outputs/system_output_5.json (deflated 61%)
# updating: system_outputs/system_output_day2_500chunk_topk5_14B_1.json (deflated 68%)
# updating: system_outputs/system_output_day_2_500chunk_topk5.json (deflated 64%)
# updating: system_outputs/system_output_3.json (deflated 68%)
# updating: system_outputs/system_output_day_2_second.json (deflated 65%)
# updating: system_outputs/system_output_day_2_1000chunk_topk5.json (deflated 64%)
# updating: system_outputs/system_output_2.json (deflated 67%)
# updating: system_outputs/system_output_7.json (deflated 59%)
# updating: system_outputs/system_output_day2_500chunk_topk5_1.5B_1.json (deflated 64%)
# updating: system_outputs/system_output_8.json (deflated 55%)
# updating: system_outputs/system_output_day_2_first.json (deflated 65%)
# ...
